# %%
for i in range(1,4):
  for j in range(1,4):
    print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %%
for i in range(1,6):
  if i==4:
    break
  print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(1,6):
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
for i in range(5):
  print(i)
else:
  print("Loop complete successfully")
# Out:
# 0
# 1
# 2
# 3
# 4
# Loop complete successfully
