# %%
ph_level=4
while ph_level<7:
  print("soil is acidic:",ph_level)
  ph_level+=0.5
print("Neutral ph")
# Out:
# Neutral ph

# %%
ph_level=8
while ph_level>7:
  print("soil is alkaline:",ph_level)
  ph_level-=0.5
print("add gypsum")
print("Neutral_ph")
# Out:
# soil is alkaline: 8
# soil is alkaline: 7.5
# add gypsum
# Neutral_ph

# %%
ph_level=float(input("Enter Ph level:"))
if ph_level<7:
  print("Soil is acidic")
  print("suitable crop:jute")
else:
  print("suiable crop:millets")
# Out:
# Enter Ph level:4
# Soil is acidic
# suitable crop:jute

# %%
temperature=18
humidity=70
if temperature>25 and humidity>60:
  print("low chance of rain today")
else:
  print("high chance of rain today")
# Out:
# high chance of rain today
