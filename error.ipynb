# %%
lst=[1,2,3]
for x in lst:
  lst.append(x)
  if len(lst)>=4:
    break
print(lst)
# Out:
# [1, 2, 3, 1]

# %%
lst1=[]
nums=[5,10,15]
for n in nums:
  n+=5
  lst1.append(n)
print(lst1)
# Out:
# [10, 15, 20]

# %%
print(5^3)
# Out:
# 6

# %%
squares=[]
nums=[1,2,3,4]
for n in nums:
  squares.append(n**2)
  print("squares",squares)
# Out:
# squares [1]
# squares [1, 4]
# squares [1, 4, 9]
# squares [1, 4, 9, 16]
