# %%
import statistics

yields=[2000,2800,2200,3000,2700]

print("===== YIELD STATISTICS=====")
print(f"Yields{yields}")
print(f"Mean:{statistics.mean(yields):.0f} kg/ha")
print(f"Median:{statistics.median(yields):.0f} kg/ha")
print(f"Std Dev:{statistics.stdev(yields):.0f} kg/ha")
print(f"Range:{min(yields):.0f} kg/ha")

total_years=10
drought_years=3
# Out:
# ===== YIELD STATISTICS=====
# Yields[2000, 2800, 2200, 3000, 2700]
# Mean:2540 kg/ha
# Median:2700 kg/ha
# Std Dev:422 kg/ha
# Range:2000 kg/ha

# %%
total_years=10
drought_years=3
prob_drought=drought_years/total_years
print(f"\nDrought Probability:{prob_drought:.0%}")
# Out:
# Drought Probability:30%

# %%
if statistics.stdev(yields)>300:
  print("High Variability- consider crop insurance!")
else:
  print("Stable yields-good predictable")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-957387738.py in <cell line: 0>()
# ----> 1 if statistics.stdev(yields)>300:
#       2   print("High Variability- consider crop insurance!")
#       3 else:
#       4   print("Stable yields-good predictable")
#
# NameError: name 'statistics' is not defined
