# %%
#string manipulation in python
crop="sugarcane"
soil_type="black soil"
print(crop)
print(soil_type)
print(len(crop))
# Out:
# sugarcane
# black soil
# 9

# %%
crop_name="sugarcane"
print(crop_name[0])
print(crop_name[-1])
print(crop_name[:5])
print(crop_name[5:])
# Out:
# s
# e
# sugar
# cane

# %%
print("sugarcane".upper())
print("sorghum".lower())
print("sugarcane".capitalize())
print("sweet potato".title())
# Out:
# SUGARCANE
# sorghum
# Sugarcane
# Sweet Potato

# %%
raw_crop=" Rice "
print(raw_crop.strip())
print("***wheat".lstrip("*"))
print("maize###".rstrip("#"))
# Out:
# Rice
# wheat
# maize

# %%
text="Organic rice and rice cultivation"
print(text.find("rice"))
print(text.count("rice"))
print("sugarcane"in text)
print("rice".isalpha())
print("2026".isdigit())
print("plot12".isalnum())
print("  ".isspace())
# Out:
# 8
# 2
# False
# True
# True
# True
# True

# %%
codes=[
    "CRP_SUGARCANE_2026",
    "CRP_WHEAT_2025",
    "FRT_BANANA_2025",
    "CRP_SWEET POTATO_2024"
]
clean_codes=[]

for code in codes:
  if code.startswith("CRP_"):
    clean_codes.append(code[4:])

print(clean_codes)
# Out:
# ['SUGARCANE_2026', 'WHEAT_2025', 'SWEET POTATO_2024']

# %%
for crop_code in codes:
 if crop_code.startswith("CRP_"):
  code,crop,year=crop_code.split("_")
  print(code,crop,year)
# Out:
# CRP SUGARCANE 2026
# CRP WHEAT 2025
# CRP SWEET POTATO 2024

# %%
raw_record="Rice,1200,Black soil**"
clean_record=raw_record.strip()
clean_record1=clean_record.rstrip("*")
crop,yield_kg,soil=clean_record1.split(",")
crop=crop.title()
print(f"crop:{crop}")
print(f"yield_kg:{yield_kg}")
print(f"soil:{soil}")
# Out:
# crop:Rice
# yield_kg:1200
# soil:Black soil

# %%
new_record="sugarcane,1800,mandya#"
clean_record=new_record.strip("#")
crop,yield_kg,district=clean_record.split(",")
crop=crop.upper()
district=district.capitalize()
print(f"crop:{crop}")
print(f"yield:{yield_kg}")
print(f"district:{district}")
# Out:
# crop:SUGARCANE
# yield:1800
# district:Mandya

# %%
def mass_to_force(mass,acceleration):
  return mass*acceleration
mass=float(input("Enter mass(kg)"))
acceleration=float(input("Enter acceleration(m/s2)"))
force=mass_to_force(mass,acceleration)
print(f"force(N)=",force)
# Out:
# Enter mass(kg)56
# Enter acceleration(m/s2)10
# force(N)= 560.0
