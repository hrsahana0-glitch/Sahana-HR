# %%
farm_data=[
    [1,"rice",45],
    [2,"wheat",30],
    [3,"maize",60]
]
print(farm_data)
print(farm_data[0])
print(farm_data[0][1])
# Out:
# [[1, 'rice', 45], [2, 'wheat', 30], [3, 'maize', 60]]
# [1, 'rice', 45]
# rice

# %%
yield_data=[
    ["rice",3200],
    ["wheat",2800],
    ["maize",4000]
]
for crop in yield_data:
  print(crop[0],"yield:",crop[1],"kg/hectare")
# Out:
# rice yield: 3200 kg/hectare
# wheat yield: 2800 kg/hectare
# maize yield: 4000 kg/hectare

# %%
crop_plan=[
    ["kharif",["rice"],["maize"]],
    ["rabi",["gram"],["wheat"]],
    ["zaid",["vegetables"]]
]
print(crop_plan[0][2])
# Out:
# ['maize']

# %%
#daily farm expenses
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
]
print(expenses[0])
# Out:
# ['day1', [1200, 500, 300]]

# %%
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
    ]
print(expenses[0])
for day in expenses:
 print(day[0],"total:",sum(day[1]))
# Out:
# ['day1', [1200, 500, 300]]
# day1 total: 2000
# day2 total: 2500
# day3 total: 1900

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure=expenses_made()
print("daily expenses:")
overall_total=0
for expenditure in total_expenditure:
   daily_total=sum(expenditure[1])
   print(expenditure[0],"expenses are",expenditure[1],"total for day:",daily_total)
   overall_total+=daily_total
print("total expenses for all days:",overall_total)
# Out:
# Enter the number of days:2
# enter the day name:monday
# enter the seed cost:1200
# enter the fertilizer cost:2300
# enter the labour cost:2345
# enter the day name:tuesday
# enter the seed cost:2340
# enter the fertilizer cost:4350
# enter the labour cost:3340
# daily expenses:
# monday expenses are [1200, 2300, 2345] total for day: 5845
# tuesday expenses are [2340, 4350, 3340] total for day: 10030
# total expenses for all days: 15875

# %%
thistuple=("apple","banana","cherry","apple","cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
thistuple=("apple","banana","cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple=("apple",)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
fruits=("apple","banana","cherry","guava","orange")
print(fruits)
(green,yellow,*red)=fruits
print(green)
print(yellow)
print(red)
# Out:
# ('apple', 'banana', 'cherry', 'guava', 'orange')
# apple
# banana
# ['cherry', 'guava', 'orange']
