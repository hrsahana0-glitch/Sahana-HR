# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,11,2):
   print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
days= int(input("Enter number of days:"))#5
total_yield = 0
for day in range (1,days+1):
  yield_today=float(input(f"Enter yield for day{day}:"))
  total_yield += yield_today
print("Total yield:",total_yield)
# Out:
# Enter number of days:5
# Enter yield for day1:5
# Enter yield for day2:6
# Enter yield for day3:7
# Enter yield for day4:8
# Enter yield for day5:9
# Total yield: 35.0

# %%
rainfall=[450,800,1200,300]
for r in rainfall:
  if r<500:
    print(r,"low rainfall")
  else:
    print(r,"sufficient rainfall")
# Out:
# 450 low rainfall
# 800 sufficient rainfall
# 1200 sufficient rainfall
# 300 low rainfall
