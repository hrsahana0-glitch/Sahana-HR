# %%
print("\n===CROP SUITABILITY CHECK===")
soil_moisture=float(input("Enter the soil moisture in %:"))
rainfall=float(input("Enter the rainfall in mm:"))
if soil_moisture>=70 and rainfall >=200:
  print("suitable for rice")
else:
  print("not suitable for rice")
# Out:
# ===CROP SUITABILITY CHECK===
# Enter the soil moisture in %:60
# Enter the rainfall in mm:155
# not suitable for rice

# %%
print("\n===FERTILIZER RECOMMENDATION SYSTEM===")
crop_name=(input("Enter the crop name:")).lower()
soil_nitrogen_level=float(input("Enter the soil nitrogen level in %:"))
if crop_name=="rice"and soil_nitrogen_level<50:
              print("APPLY UREA")
elif crop_name=="wheat" and soil_nitrogen_level<40:
           print("APPLY DAP")
else:
           print("FERTILIZER NOT REQUIRED")
# Out:
# ===FERTILIZER RECOMMENDATION SYSTEM===
# Enter the crop name:wheat
# Enter the soil nitrogen level in %:30
# APPLY DAP

# %%
print("\n===CROP YIELD CLASSIFICATION===")
crop_yield=float(input("Enter the crop yield in q:"))
if crop_yield>=50:
  print("HIGH YIELD")
elif crop_yield >= 30:
  print("MEDIUM YIELD")
else:
  print("LOW YIELD")
# Out:
# ===CROP YIELD CLASSIFICATION===
# Enter the crop yield in q:28
# LOW YIELD

# %%
print("\n===IRRIGATION SCHEDULING===")
for field in range(1,6):
  print("irrigating field",field)
# Out:
# ===IRRIGATION SCHEDULING===
# irrigating field 1
# irrigating field 2
# irrigating field 3
# irrigating field 4
# irrigating field 5

# %%
print("\n===PEST MONITORING SYSTEM===")
pest_count=int(input("Enter pest count:"))
if pest_count > 0:
  print(pest_count,"MONITORING")
else:
  print(pest_count,"MONITORING STOPPED")
# Out:
# ===PEST MONITORING SYSTEM===
# Enter pest count:0
# 0 MONITORING STOPPED

# %%
print("\n===CROP LIST DISPLAY===")
crops=["RICE","WHEAT","MAIZE","MILLET"]
for crop in crops:
  print(crop)
# Out:
# ===CROP LIST DISPLAY===
# RICE
# WHEAT
# MAIZE
# MILLET

# %%
print("\n===CROP AVAILABILITY CHECK===")
crops=["RICE","WHEAT","MAIZE"]
crop_name=(input("Enter crop name"))
if crop_name in crops:
  print("CROP AVAILABLE")
else:
  print("CROP NOT AVAILABLE")
# Out:
# ===CROP AVAILABILITY CHECK===
# Enter crop nameragi
# CROP NOT AVAILABLE

# %%
print("\n===AVERAGE RAINFALL ANALYSIS")
rainfall_1=float(input("Enter rainfall of day 1:"))
rainfall_2=float(input("Enter rainfall of day 2:"))
rainfall_3=float(input("Enter rainfall of day 3:"))
rainfall_4=float(input("Enter rainfall of day 4:"))
rainfall_5=float(input("Enter rainfall of day 5:"))
total_rainfall=rainfall_1+rainfall_2+rainfall_3+rainfall_4+rainfall_5
average_rainfall=total_rainfall/5
print("Average rainfall:",average_rainfall)
if average_rainfall>=100:
  print("SUFFICIENT RAINFALL")
else:
  print("INSUFFICIENT RAINFALL")
# Out:
# ===AVERAGE RAINFALL ANALYSIS
# Enter rainfall of day 1:123
# Enter rainfall of day 2:217
# Enter rainfall of day 3:135
# Enter rainfall of day 4:155
# Enter rainfall of day 5:111
# Average rainfall: 148.2
# SUFFICIENT RAINFALL

# %%
print("\n===SEED QUALITY EVALUATION===")
germination_percentage=float(input("Enter gemination percentage:"))
moisture_content=float(input("Enter moisture content:"))
if germination_percentage>=85:
  if soil_moisture<=12:
    print("HIGH QUALITY SEED")
  else:
    print("MOISTURE TOO HIGH")
else:
  print("LOW GERMINATION")
# Out:
# ===SEED QUALITY EVALUATION===
# Enter gemination percentage:85
# Enter moisture content:11
# MOISTURE TOO HIGH

# %%
print("\n===HARVEST READINESS MONITORING===")
while True:
    crop_maturity_percentage=float(input("Enter crop maturity percentage:"))
    if crop_maturity_percentage>=100:
        print ("CROP READY FOR HARVEST ")
        break
# Out:
# ===HARVEST READINESS MONITORING===
# Enter crop maturity percentage:120
# CROP READY FOR HARVEST
