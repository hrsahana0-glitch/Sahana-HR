# %%
farmer_name=str(input("Enter Farmer Name: "))
crop_name=str(input("Enter Crop Name: "))
total_land_area=float(input("Enter Total Land Area (acres): "))
water_requirement_per_acre=float(input("Enter Water Requirement per Acre (liters): "))
current_water_available=float(input("Enter Current Water Availability (liters): "))
fertilizer_applied_status=bool(input("Enter Fertilizer Applied status (True/False): "))
sensor_ID=str(input("Enter Sensor ID: "))
authorized_sensor_ID=str(input("Enter Authorized Sensor ID: "))
total_water_required_for_irrigation=(total_land_area*water_requirement_per_acre)-current_water_available
print("Total Water Required for Irrigation (litres): ",total_water_required_for_irrigation)
water_balance=total_water_required_for_irrigation-current_water_available
a=current_water_available
a-=500
print ("After -=:",a)
b=total_land_area
b+=1
print ("After +=:",b)
x=water_requirement_per_acre
y=current_water_available
print("x=y:",x==y)
print("x<y:",x<y)
print("x>y:",x>y)
print("x>=y:",x>=y)
print("x<=y:",x<=y)
irrigation = True
solid_moisture = False
print("AND:",irrigation and solid_moisture)
print("OR:",irrigation or solid_moisture)
print("NOT:",not irrigation)
government_approved_crops=["wheat","paddy","maize"]
print(crop_name in"government_approved_crops:",crop_name in government_approved_crops)
print(crop_name not in"government_approved_crops:",crop_name not in government_approved_crops)

# Corrected: Assign sensor_ID and authorized_sensor_ID directly to a and b
a = sensor_ID
b = authorized_sensor_ID

print(f"sensor_ID:{a}")
print(f"authorized_sensor_ID:{b}")

if a is b:
   print("a is b:",a is b)
else:
    print("a is not b:",a is not b)

# Note: Bitwise operations (&, |, ^) are generally not meaningful for strings like sensor IDs
# and can only be performed on integers.
# If you intend to compare their integer values, you would need to convert them first.
# For now, I'm commenting them out to resolve the TypeError with strings.
# If a future requirement is to perform bitwise operations, the types must be integers.
# For example, if sensor_ID and authorized_sensor_ID were guaranteed to be string representations of integers, you'd do:
# a_int = int(a)
# b_int = int(b)
# print("Bitwise AND (&):",a_int & b_int)
# print("Bitwise OR (|):",a_int | b_int)
# print("Bitwise XOR (^):",a_int ^ b_int)

# For the current string values, these operations are invalid.
# print("Bitwise AND (&):",a&b)
# print("Bitwise OR (|):",a|b)
# print("Bitwise XOR (^):",a^b)
# Out:
# Enter Farmer Name: Ramesh H S
# Enter Crop Name: Foxtail millet
# Enter Total Land Area (acres): 3
# Enter Water Requirement per Acre (liters): 30000
# Enter Current Water Availability (liters): 10000
# Enter Fertilizer Applied status (True/False): True
# Enter Sensor ID: 2217
# Enter Authorized Sensor ID: 2217
# Total Water Required for Irrigation (litres):  80000.0
# After -=: 9500.0
# After +=: 4.0
# x=y: False
# x<y: False
# x>y: True
# x>=y: True
# x<=y: False
# AND: False
# OR: True
# NOT: False
# False False
# True True
# sensor_ID:2217
# authorized_sensor_ID:2217
# a is not b: True
