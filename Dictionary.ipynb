# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
print(thisdict)
# Out:
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2024}

# %%
thisdict={
    "crop":"rice",
    "organic":"True",
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'rice', 'organic': 'True', 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
thisdict=dict(
    farmer_name=["Ramesh","harish","suresh"],
    age=[52,48,65],
    village=["MYSURU"]
)
print(thisdict)
# Out:
# {'farmer_name': ['Ramesh', 'harish', 'suresh'], 'age': [52, 48, 65], 'village': ['MYSURU']}

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict["variety"]
print(x)
x=thisdict.get("year")
print(x)
x=thisdict.keys()
print(x)
# Out:
# IR-64
# 2024
# dict_keys(['crop', 'variety', 'year'])

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict.keys()
print(x)
thisdict["season"]="kharif"
print(x)

x=thisdict.values()
print(x)

x=farm.values()
print(x)
farm["year"]=2029
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])
# dict_values(['rice', 'IR-64', 2024, 'kharif'])
# dict_values(['rice', 'IR-64', 2029, 'kharif'])
# dict_values(['rice', 'IR-64', 2029, 'kharif'])

# %%
x_keys=tuple(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))
# Out:
# ('crop', 'variety', 'year', 'season')
# ['rice', 'IR-64', 2024, 'kharif']
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024), ('season', 'kharif'))

# %%
x_keys=list(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(list(pairs))
# Out:
# ['crop', 'variety', 'year', 'season']
# ['rice', 'IR-64', 2024, 'kharif']
# [('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024), ('season', 'kharif')]

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
if "crop" in thisdict:
  print("Yes, crop is one of the keys in the thisdict dictionary ")
# Out:
# Yes, crop is one of the keys in the thisdict dictionary

# %%
#original dictionary
student={
    "name":"SAHANA H R",
    "roll_no":2217,
    "branch":"B.Sc.",
    "marks":581
}
print("Original dictionary:",student)

student_copy=student.copy()
print("COPIED DICTIONARY:",student_copy)
# Out:
# Original dictionary: {'name': 'SAHANA H R', 'roll_no': 2217, 'branch': 'B.Sc.', 'marks': 581}
# COPIED DICTIONARY: {'name': 'SAHANA H R', 'roll_no': 2217, 'branch': 'B.Sc.', 'marks': 581}

# %%
removed_value=student.pop("marks")
print("Remove value:",removed_value)
print("After pop():",student)
# Out:
# Remove value: 581
# After pop(): {'name': 'SAHANA H R', 'roll_no': 2217, 'branch': 'B.Sc.'}

# %%
last_item=student.popitem()
print("Removed item:",last_item)
print("After popitem():",student)
# Out:
# Removed item: ('roll_no', 2217)
# After popitem(): {'name': 'SAHANA H R'}

# %%
student.update({"passing year":2026,"branch":"B.Sc."})
print("After update():",student)
# Out:
# After update(): {'name': 'SAHANA H R', 'passing year': 2026, 'branch': 'B.Sc.'}

# %%
student.clear()
print("After clear():",student)
# Out:
# After clear(): {}

# %%
student={
    "name":"SAHANA H R",
    "roll_no":2217,
    "branch":"B.Sc.",
    "marks":581
}
del student
print("After deletion",student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1927445016.py in <cell line: 0>()
#       6 }
#       7 del student
# ----> 8 print("After deletion",student)
#
# NameError: name 'student' is not defined

# %%
student={
    "name":""
}
