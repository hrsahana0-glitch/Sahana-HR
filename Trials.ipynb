# %%
import pandas as pd
df=pd.DataFrame({
    'Name':['Samrudh','Punya','Daksha','Jeeva','Sagar'],
    'Degree':['Commerce','Commerce','Science','Arts','Science'],
    'Grade':[8.0,9.0,9.0,7.5,9.5]
})
print(df)
# Out:
#       Name    Degree  Grade
# 0  Samrudh  Commerce    8.0
# 1    Punya  Commerce    9.0
# 2   Daksha   Science    9.0
# 3    Jeeva      Arts    7.5
# 4    Sagar   Science    9.5

# %%
import matplotlib.pyplot as plt
df.plot(kind='bar',x='Name',y='Grade')
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot(kind='scatter',x='Name',y='Grade')
# Out:
# <Axes: xlabel='Name', ylabel='Grade'>
